# %%
import pandas as pd
fata=pd.read_csv('options.csv')
fdata.head(1000)
# Out:
# C:\Users\Administrator\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,8,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                DateCode          时间  OptionsCode  WholeDayOpen  WholeDayHigh  \
# 0    20170104_132010018  2017-01-04    132010018         650.0         650.0
# 1    20170104_132010118  2017-01-04    132010118           0.0           0.0
# 2    20170104_132010218  2017-01-04    132010218           0.0           0.0
# 3    20170104_132010318  2017-01-04    132010318           0.0           0.0
# 4    20170104_132010518  2017-01-04    132010518           0.0           0.0
# ..                  ...         ...          ...           ...           ...
# 995  20170104_142036218  2017-01-04    142036218           0.0           0.0
# 996  20170104_142036518  2017-01-04    142036518           0.0           0.0
# ...

# %%
fdata.describe()
# Out:
#         OptionsCode  WholeDayOpen  WholeDayHigh   WholeDayLow  WholeDayClose  \
# count  3.567694e+06  3.567694e+06  3.567694e+06  3.567694e+06   3.567694e+06
# mean   1.547259e+08  2.455560e+01  2.619204e+01  2.302928e+01   2.445090e+01
# std    2.360856e+07  1.881537e+02  1.927197e+02  1.845273e+02   1.885030e+02
# min    1.300600e+08  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    1.361030e+08  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    1.441107e+08  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 75%    1.840377e+08  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# max    1.992480e+08  2.285000e+04  2.285000e+04  2.285000e+04   2.285000e+04
#
#        DaySessionOpen  DaySessionHigh  DaySessionLow  DaySessionClose  \
# count    3.567694e+06    3.567694e+06   3.567694e+06     3.567694e+06
# mean     2.003080e+01    2.097014e+01   1.916712e+01     2.002161e+01
# ...

# %%
fdata.rename(columns={'TradingVolume':'交易量','Date':'时间'},inplace = True)
fdata.head(1000)
# Out:
#                DateCode          时间  OptionsCode  WholeDayOpen  WholeDayHigh  \
# 0    20170104_132010018  2017-01-04    132010018         650.0         650.0
# 1    20170104_132010118  2017-01-04    132010118           0.0           0.0
# 2    20170104_132010218  2017-01-04    132010218           0.0           0.0
# 3    20170104_132010318  2017-01-04    132010318           0.0           0.0
# 4    20170104_132010518  2017-01-04    132010518           0.0           0.0
# ..                  ...         ...          ...           ...           ...
# 995  20170104_142036218  2017-01-04    142036218           0.0           0.0
# 996  20170104_142036518  2017-01-04    142036518           0.0           0.0
# 997  20170104_142036718  2017-01-04    142036718           0.0           0.0
# 998  20170104_142036818  2017-01-04    142036818           0.0           0.0
# 999  20170104_142037018  2017-01-04    142037018           0.0           0.0
#
# ...

# %%
fdata.plot(kind='scatter',x='时间',y='交易量')
# Out:
# <AxesSubplot:xlabel='时间', ylabel='交易量'>
# C:\Users\Administrator\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Administrator\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 38388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Administrator\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Administrator\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Administrator\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
